# %%
import pandas as pd

# %%
drinks=pd.read_csv('drinks.csv')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.groupby('continent')['beer_servings'].mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent')['beer_servings'].agg(['count','min','max','mean'])
# Out:
#                count  min  max        mean
# continent
# Africa            53    0  376   61.471698
# Asia              44    0  247   37.045455
# Europe            45    0  361  193.777778
# North America     23    1  285  145.434783
# Oceania           16    0  306   89.687500
# South America     12   93  333  175.083333

# %%
drinks.groupby('continent')[['beer_servings','wine_servings']].mean()
# Out:
#                beer_servings  wine_servings
# continent
# Africa             61.471698      16.264151
# Asia               37.045455       9.068182
# Europe            193.777778     142.222222
# North America     145.434783      24.521739
# Oceania            89.687500      35.625000
# South America     175.083333      62.416667

# %%
drinks.groupby(['continent','country'])[['beer_servings','wine_servings']].mean()
# Out:
#                             beer_servings  wine_servings
# continent     country
# Africa        Algeria                25.0           14.0
#               Angola                217.0           45.0
#               Benin                  34.0           13.0
#               Botswana              173.0           35.0
#               Burkina Faso           25.0            7.0
# ...                                   ...            ...
# South America Paraguay              213.0           74.0
#               Peru                  163.0           21.0
#               Suriname              128.0            7.0
#               Uruguay               115.0          220.0
#               Venezuela             333.0            3.0
#
# [193 rows x 2 columns]

# %%
drinks.groupby(['continent','country'])[['beer_servings','wine_servings']].agg(['count','min','max','mean'])
# Out:
#                            beer_servings                  wine_servings       \
#                                    count  min  max   mean         count  min
# continent     country
# Africa        Algeria                  1   25   25   25.0             1   14
#               Angola                   1  217  217  217.0             1   45
#               Benin                    1   34   34   34.0             1   13
#               Botswana                 1  173  173  173.0             1   35
#               Burkina Faso             1   25   25   25.0             1    7
# ...                                  ...  ...  ...    ...           ...  ...
# South America Paraguay                 1  213  213  213.0             1   74
#               Peru                     1  163  163  163.0             1   21
#               Suriname                 1  128  128  128.0             1    7
#               Uruguay                  1  115  115  115.0             1  220
# ...

# %%
new_drinks=drinks.groupby(['continent','country'])[['beer_servings','wine_servings']].agg(['count','min','max','mean'])

# %%
new_drinks.loc['Africa',:]
# Out:
#                          beer_servings                  wine_servings       \
#                                  count  min  max   mean         count  min
# country
# Algeria                              1   25   25   25.0             1   14
# Angola                               1  217  217  217.0             1   45
# Benin                                1   34   34   34.0             1   13
# Botswana                             1  173  173  173.0             1   35
# Burkina Faso                         1   25   25   25.0             1    7
# Burundi                              1   88   88   88.0             1    0
# Cabo Verde                           1  144  144  144.0             1   16
# Cameroon                             1  147  147  147.0             1    4
# Central African Republic             1   17   17   17.0             1    1
# Chad                                 1   15   15   15.0             1    1
# ...
