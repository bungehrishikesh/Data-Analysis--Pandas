# %%
import pandas as pd

# %%
drinks=pd.read_csv('drinks.csv')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks[(drinks['continent']=='Africa')]
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 2                     Algeria             25                0             14
# 4                      Angola            217               57             45
# 18                      Benin             34                4             13
# 22                   Botswana            173               35             35
# 26               Burkina Faso             25                7              7
# 27                    Burundi             88                0              0
# 28              Cote d'Ivoire             37                1              7
# 29                 Cabo Verde            144               56             16
# 31                   Cameroon            147                1              4
# 33   Central African Republic             17                2              1
# 34                       Chad             15                1              1
# ...

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks[(drinks['continent']=='Africa') & (drinks['wine_servings']>=50)]
# Out:
#                  country  beer_servings  spirit_servings  wine_servings  \
# 55     Equatorial Guinea             92                0            233
# 62                 Gabon            347               98             59
# 148  Sao Tome & Principe             56               38            140
# 152           Seychelles            157               25             51
# 159         South Africa            225               76             81
#
#      total_litres_of_pure_alcohol continent
# 55                            5.8    Africa
# 62                            8.9    Africa
# 148                           4.2    Africa
# 152                           4.1    Africa
# 159                           8.2    Africa

# %%
drinks[(drinks['continent']=='Africa') | (drinks['wine_servings']>=50)]
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
# 6    Argentina            193               25            221
# ..         ...            ...              ...            ...
# 183   Tanzania             36                6              1
# 184        USA            249              158             84
# 185    Uruguay            115               35            220
# 191     Zambia             32               19              4
# 192   Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 1                             4.9         Europe
# 2                             0.7         Africa
# 3                            12.4         Europe
# ...

# %%
Africa=drinks[(drinks['continent']=='Africa') | (drinks['wine_servings']>=50)]

# %%
Africa.loc[:10,'country':'wine_servings']
# Out:
#      country  beer_servings  spirit_servings  wine_servings
# 1    Albania             89              132             54
# 2    Algeria             25                0             14
# 3    Andorra            245              138            312
# 4     Angola            217               57             45
# 6  Argentina            193               25            221
# 8  Australia            261               72            212
# 9    Austria            279               75            191

# %%
drinks['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
#Multiple OR

# %%
drinks[drinks['continent'].isin(['Asia','Oceania','South America'])]
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 6      Argentina            193               25            221
# 8      Australia            261               72            212
# 12       Bahrain             42               63              7
# 13    Bangladesh              0                0              0
# ..           ...            ...              ...            ...
# 186   Uzbekistan             25              101              8
# 187      Vanuatu             21               18             11
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 6                             8.3  South America
# ...
